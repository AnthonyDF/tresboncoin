# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
logs = pd.read_csv("../../tresboncoin/parameterlog.csv")

# %%
logs
# Out:
#                   date  model__max_depth  model__min_samples_split  \
# 0   03/08/2021 - 01h15             888.0                       6.0
# 1   03/08/2021 - 01h25             211.0                       8.0
# 2   03/08/2021 - 01h26               NaN                       NaN
# 3   05/08/2021 - 00h13               NaN                       NaN
# 4   04/08/2021 - 16h02             913.0                      10.0
# 5   04/08/2021 - 22h26             371.0                       2.0
# 6   04/08/2021 - 22h37              43.0                       6.0
# 7   04/08/2021 - 23h21             480.0                       8.0
# 8   05/08/2021 - 16h02             413.0                       4.0
# 9   06/08/2021 - 16h02             841.0                       2.0
# 10  07/08/2021 - 16h03             906.0                       2.0
# 11  08/08/2021 - 16h02             537.0                       4.0
#
#    preprocessor__scaler         rmse                           estimator  \
# ...
