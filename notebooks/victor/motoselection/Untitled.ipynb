# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/victor/code/victorbnnt/tresboncoin/notebooks/victor/motoselection'

# %%
data = pd.read_csv("../../../tresboncoin/data/scraping_outputs/moto-selection.csv")

# %%
data.shape
# Out:
# (5744, 18)

# %%
data.head()
# Out:
#                   uniq_id  reference bike_type  bike_size  bike_year  \
# 0  moto-selection-1188962    1188962   SCOOTER        125       2018
# 1  moto-selection-1189047    1189047  ROUTIÈRE        689       2021
# 2  moto-selection-1189029    1189029     TRAIL       1000       2014
# 3  moto-selection-1188958    1188958  ROADSTER        600       2003
# 4  moto-selection-1188980    1188980  ROADSTER        650       2015
#
#    bike_year_circulation  bike_km  bike_color  bike_warranty  \
# 0                      0     7650         NaN            NaN
# 1                      0      650         NaN            NaN
# 2                      0    11818         NaN            NaN
# 3                      0    41200         NaN            NaN
# 4                      0     1545         NaN            NaN
#
#                                     bike_description  price bike_brand  \
# 0    ABS,Saute vent,Financement possible,Aucun co...   2590        SYM
# ...

# %%
data[data["vendor_city"].str.contains("La Garenne Colombes")].sort_values(by="bike_size")
# Out:
#                      uniq_id  reference bike_type  bike_size  bike_year  \
# 0     moto-selection-1188962    1188962   SCOOTER        125       2018
# 3678  moto-selection-1189088    1189088   SCOOTER        125       2019
# 4376  moto-selection-1189088    1189088   SCOOTER        125       2019
# 1886  moto-selection-1183420    1183420   SCOOTER        300       2019
# 1837  moto-selection-1187633    1187633   SCOOTER        400       2014
# 3790  moto-selection-1189207    1189207     TRAIL        700       2019
# 511   moto-selection-1188181    1188181  ROADSTER        850       2020
# 4460  moto-selection-1189768    1189768  ROADSTER        850       2018
# 4886  moto-selection-1190149    1190149  ROADSTER        850       2016
# 1850  moto-selection-1056322    1056322    CUSTOM        950       2016
# 1880  moto-selection-1185057    1185057  ROUTIÈRE       1300       2020
# 4579  moto-selection-1185057    1185057  ROUTIÈRE       1300       2020
#
# ...
