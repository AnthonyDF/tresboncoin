# %%
from scraping import scraping
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('../scraping_outputs/motovente.csv')
df
# Out:
#         brand           model          version  engine_size     bike_type  \
# 0         BMW          R 1200              ABS         1200      Routière
# 1       Honda       CB HORNET  CB 600 F HORNET          600      Roadster
# 2      Ducati  MONSTER 1200 S   MONSTER 1200 S         1200      Roadster
# 3      Ducati     MONSTER 797      MONSTER 797          803      Roadster
# 4      Yamaha       YXZ 1000R        YXZ 1000R         1000  Quad Loisirs
# ...       ...             ...              ...          ...           ...
# 3613  Piaggio             NaN              NaN          300       Scooter
# 3614    Honda              CB           CB500F          500      Roadster
# 3615   Yamaha       FZ8 FAZER              FZ8          800      Roadster
# 3616      BMW          R 1200        R 1200 RT         1200      Routière
# 3617    Honda        CB 650 R         CB 650 R          650      Roadster
#
#       bike_year year_circulation  mileage bike_color warranty  reference  \
# 0          2012       11-10-2012    14000       Bleu      NaN    1656661
# 1          2003       25-06-2003    41200       Gris      non    1872847
# 2          2018       11-04-2018     6027      Rouge      non    1869268
# 3          2017       16-06-2017     2801      Blanc      non    1873924
# 4          2021       05-01-2021     1800     Argent      non    1861867
# ...         ...              ...      ...        ...      ...        ...
# 3613       2020       07-07-2020      500     Argent      non    1855753
# 3614       2016       29-07-2016    41969      Blanc      non    1873394
# 3615       2012       04-01-2012    34060     Argent      non    1874558
# 3616       2006       27-06-2006    39838       Gris      non    1874562
# 3617       2020       15-05-2020     2947   Bordeaux      non    1860233
#
#                  uniqid     source                scraped_date  \
# 0     motovente-1656661  motovente  2021-06-22 11:24:20.733216
# 1     motovente-1872847  motovente  2021-06-22 11:24:20.761468
# 2     motovente-1869268  motovente  2021-06-22 11:24:20.784830
# 3     motovente-1873924  motovente  2021-06-22 11:24:20.809699
# 4     motovente-1861867  motovente  2021-06-22 11:24:20.834758
# ...                 ...        ...                         ...
# 3613  motovente-1855753  motovente  2021-06-22 11:35:11.583280
# 3614  motovente-1873394  motovente  2021-06-22 11:35:49.231165
# 3615  motovente-1874558  motovente  2021-06-22 11:35:58.902488
# 3616  motovente-1874562  motovente  2021-06-22 11:36:34.884037
# 3617  motovente-1860233  motovente  2021-06-22 11:37:45.965229
#
#                                                     url      energy  \
# 0     http://motovente.com/moto-occasion/annonce-mot...  Essence 4t
# 1     http://motovente.com/moto-occasion/annonce-mot...         NaN
# 2     http://motovente.com/moto-occasion/annonce-mot...         NaN
# 3     http://motovente.com/moto-occasion/annonce-mot...         NaN
# 4     http://motovente.com/quad-occasion/annonce-qua...         NaN
# ...                                                 ...         ...
# 3613  http://motovente.com/scooter-occasion/annonce-...         NaN
# 3614  http://motovente.com/moto-occasion/annonce-mot...         NaN
# 3615  http://motovente.com/moto-occasion/annonce-mot...         NaN
# 3616  http://motovente.com/moto-occasion/annonce-mot...         NaN
# 3617  http://motovente.com/moto-occasion/annonce-mot...         NaN
#
#      first_hand homologue  price
# 0           NaN       NaN  12000
# 1           NaN       NaN   3490
# 2           Oui       NaN  13990
# 3           Oui       NaN   7990
# 4           Oui       NaN  33900
# ...         ...       ...    ...
# 3613        NaN       NaN   3350
# 3614        NaN       NaN   4400
# 3615        NaN       NaN   4990
# 3616        NaN       NaN   6990
# 3617        NaN       NaN   7499
#
# [3618 rows x 19 columns]

# %%
df.to_csv('../scraping_outputs/motovente.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-16b79f74a23e> in <module>
# ----> 1 df.engine_size = df.engine_size.str.replace(' cm3', '')
#       2 df.engine_size = df.engine_size.astype(float)
#       3 df.mileage = df.mileage.str.replace(' km', '')
#       4 df.mileage = df.mileage.astype(float)
#       5 df.to_csv('../scraping_outputs/motovente.csv', index=False)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5454             or name in self._accessors
#    5455         ):
# -> 5456             return object.__getattribute__(self, name)
#    5457         else:
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     152         from pandas.core.arrays.string_ import StringDtype
#     153
# --> 154         self._inferred_dtype = self._validate(data)
#     155         self._is_categorical = is_categorical_dtype(data.dtype)
#     156         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     216
#     217         if inferred_dtype not in allowed_types:
# --> 218             raise AttributeError("Can only use .str accessor with string values!")
#     219         return inferred_dtype
#     220
#
# AttributeError: Can only use .str accessor with string values!

# %%
scraping()
# Out:
# page number: 1
# page number: 2
# page number: 3
# page number: 4
# page number: 5
# page number: 6
# page number: 7
# page number: 8
# page number: 9
# page number: 10
# page number: 11
# page number: 12
# page number: 13
# page number: 14
# page number: 15
# page number: 16
# page number: 17
# page number: 18
# page number: 19
# page number: 20
# page number: 21
# page number: 22
# page number: 23
# page number: 24
# page number: 25
# page number: 26
# page number: 27
# page number: 28
# page number: 29
# page number: 30
# page number: 31
# page number: 32
# page number: 33
# page number: 34
# page number: 35
# page number: 36
# page number: 37
# page number: 38
# page number: 39
# page number: 40
# page number: 41
# page number: 42
# page number: 43
# page number: 44
# page number: 45
# page number: 46
# page number: 47
# page number: 48
# page number: 49
# page number: 50
# page number: 51
# page number: 52
# page number: 53
# page number: 54
# page number: 55
# page number: 56
# page number: 57
# page number: 58
# page number: 59
# page number: 60
# page number: 61
# page number: 62
# page number: 63
# page number: 64
# page number: 65
# page number: 66
# page number: 67
# page number: 68
# page number: 69
# page number: 70
# page number: 71
# page number: 72
# page number: 73
# page number: 74
# page number: 75
# page number: 76
# page number: 77
# page number: 78
# page number: 79
# page number: 80
# page number: 81
# page number: 82
# page number: 83
# page number: 84
# page number: 85
# page number: 86
# page number: 87
# page number: 88
# page number: 89
# page number: 90
# page number: 91
# page number: 92
# page number: 93
# page number: 94
# page number: 95
# page number: 96
# page number: 97
# page number: 98
# page number: 99
# page number: 100
# page number: 101
# page number: 102
# page number: 103
# page number: 104
# page number: 105
# page number: 106
# page number: 107
# page number: 108
# page number: 109
# page number: 110
# page number: 111
# page number: 112
# page number: 113
# page number: 114
# page number: 115
# page number: 116
# page number: 117
# page number: 118
# page number: 119
# page number: 120
# page number: 121
# page number: 122
# page number: 123
# page number: 124
# page number: 125
# page number: 126
# page number: 127
# page number: 128
# page number: 129
# page number: 130
# page number: 131
# page number: 132
# page number: 133
# page number: 134
# page number: 135
# page number: 136
# page number: 137
# page number: 138
# page number: 139
# page number: 140
# page number: 141
# page number: 142
# page number: 143
# page number: 144
# page number: 145
# page number: 146

# %% [markdown]
# # Check duplicates

# %%
df=pd.read_csv("moto-occasion.csv")
df['reference+price'] = df['reference']  + df['price'].astype(str)
df['reference+price'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b74808e51053> in <module>
# ----> 1 df=pd.read_csv("moto-occasion.csv")
#       2 df['reference+price'] = df['reference']  + df['price'].astype(str)
#       3 df['reference+price'].value_counts()
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'moto-occasion.csv'

# %% [markdown]
# # Use this to remove duplicates in a dataframe

# %%
df=pd.read_csv("moto-occasion.csv")
df.drop_duplicates(subset=['reference','price'], inplace=True)
df.to_csv("moto-occasion.csv", index=False)

# %% [markdown]
# # Explore data

# %%
df = pd.read_csv("moto-occasion.csv")
df.shape

# %%
df.reference.value_counts()

# %%
df[df.reference == 'WT139599']

# %%
df.bike_brand.value_counts()

# %%
df.bike_model.value_counts()

# %% [markdown]
# ## Bike Price

# %%
df.price.mean()

# %%
fig = plt.figure(figsize=(16, 5))
feat = "price"
sns.histplot(df[feat], palette='Blues', stat='density', bins=30)
sns.kdeplot(df[feat], color='red')
plt.xlim(0, 60000)

# %% [markdown]
# ## Bike km

# %%
fig = plt.figure(figsize=(16, 5))
feat = "bike_km"
sns.histplot(df[feat], palette='Blues', stat='density', bins=50)
plt.xlim(0, 150000)

# %% [markdown]
# ## Bike year

# %%
fig = plt.figure(figsize=(16, 5))
feat = "bike_year"
sns.histplot(df[feat], palette='Blues', stat='density', bins=1500)
plt.xlim(1980, datetime.now().year)

# %% [markdown]
# ## Correlation Matrix

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()
